# %%
# %matplotlib inline

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('house_prices.csv')

# %%
df.head()
# Out:
#    Index                                              Title  \
# 0      0  1 BHK Ready to Occupy Flat for sale in Srushti...
# 1      1  2 BHK Ready to Occupy Flat for sale in Dosti V...
# 2      2  2 BHK Ready to Occupy Flat for sale in Sunrise...
# 3      3        1 BHK Ready to Occupy Flat for sale Kasheli
# 4      4  2 BHK Ready to Occupy Flat for sale in TenX Ha...
#
#                                          Description Amount(in rupees)  \
# 0  Bhiwandi, Thane has an attractive 1 BHK Flat f...           42 Lac
# 1  One can find this stunning 2 BHK flat for sale...           98 Lac
# 2  Up for immediate sale is a 2 BHK apartment in ...          1.40 Cr
# 3  This beautiful 1 BHK Flat is available for sal...           25 Lac
# 4  This lovely 2 BHK Flat in Pokhran Road, Thane ...          1.60 Cr
#
#    Price (in rupees) location Carpet Area         Status         Floor  \
# 0             6000.0    thane    500 sqft  Ready to Move  10 out of 11
# ...

# %%
# Dropping the Index columns
df.drop('Index', axis =1, inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 187531 entries, 0 to 187530
# Data columns (total 20 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   Title              187531 non-null  object
#  1   Description        184508 non-null  object
#  2   Amount(in rupees)  187531 non-null  object
#  3   Price (in rupees)  169866 non-null  float64
#  4   location           187531 non-null  object
#  5   Carpet Area        106858 non-null  object
#  6   Status             186916 non-null  object
#  7   Floor              180454 non-null  object
#  8   Transaction        187448 non-null  object
#  9   Furnishing         184634 non-null  object
#  10  facing             117298 non-null  object
#  11  overlooking        106095 non-null  object
#  12  Society            77853 non-null   object
#  13  Bathroom           186703 non-null  object
#  14  Balcony            138596 non-null  object
# ...

# %%
df.describe()
# Out:
#        Price (in rupees)  Dimensions  Plot Area
# count       1.698660e+05         0.0        0.0
# mean        7.583772e+03         NaN        NaN
# std         2.724171e+04         NaN        NaN
# min         0.000000e+00         NaN        NaN
# 25%         4.297000e+03         NaN        NaN
# 50%         6.034000e+03         NaN        NaN
# 75%         9.450000e+03         NaN        NaN
# max         6.700000e+06         NaN        NaN

# %% [markdown]
# ### Data CLeaning

# %%
# Missing values
missing_percentage = df.isnull().mean() * 100
missing_percentage
# Out:
# Title                  0.000000
# Description            1.612000
# Amount(in rupees)      0.000000
# Price (in rupees)      9.419776
# location               0.000000
# Carpet Area           43.018488
# Status                 0.327946
# Floor                  3.773776
# Transaction            0.044259
# Furnishing             1.544811
# facing                37.451408
# overlooking           43.425354
# Society               58.485264
# Bathroom               0.441527
# Balcony               26.094352
# Car Parking           55.114621
# Ownership             34.936624
# Super Area            57.422506
# Dimensions           100.000000
# Plot Area            100.000000
# dtype: float64

# %%
#  Dropping ccolumns with more than 50% missing values
# df.drop(['Car Parking', 'Super Area', 'Dimensions', "Society", "Plot Area"], axis = 1, inplace = True)
missing_percentage_50 =  missing_percentage[missing_percentage > 50]
missing_percentage_50
# Out:
# Society         58.485264
# Car Parking     55.114621
# Super Area      57.422506
# Dimensions     100.000000
# Plot Area      100.000000
# dtype: float64

# %%
missing_percentage_50.index
# Out:
# Index(['Society', 'Car Parking', 'Super Area', 'Dimensions', 'Plot Area'], dtype='object')

# %%
df.drop(missing_percentage_50.index, axis = 1, inplace = True)

# %%
df.head()
# Out:
#                                                Title  \
# 0  1 BHK Ready to Occupy Flat for sale in Srushti...
# 1  2 BHK Ready to Occupy Flat for sale in Dosti V...
# 2  2 BHK Ready to Occupy Flat for sale in Sunrise...
# 3        1 BHK Ready to Occupy Flat for sale Kasheli
# 4  2 BHK Ready to Occupy Flat for sale in TenX Ha...
#
#                                          Description Amount(in rupees)  \
# 0  Bhiwandi, Thane has an attractive 1 BHK Flat f...           42 Lac
# 1  One can find this stunning 2 BHK flat for sale...           98 Lac
# 2  Up for immediate sale is a 2 BHK apartment in ...          1.40 Cr
# 3  This beautiful 1 BHK Flat is available for sal...           25 Lac
# 4  This lovely 2 BHK Flat in Pokhran Road, Thane ...          1.60 Cr
#
#    Price (in rupees) location Carpet Area         Status         Floor  \
# 0             6000.0    thane    500 sqft  Ready to Move  10 out of 11
# 1            13799.0    thane    473 sqft  Ready to Move   3 out of 22
# ...

# %%
df.shape
# Out:
# (187531, 15)

# %%
df.isnull().mean() * 100
# Out:
# Title                 0.000000
# Description           1.612000
# Amount(in rupees)     0.000000
# Price (in rupees)     9.419776
# location              0.000000
# Carpet Area          43.018488
# Status                0.327946
# Floor                 3.773776
# Transaction           0.044259
# Furnishing            1.544811
# facing               37.451408
# overlooking          43.425354
# Bathroom              0.441527
# Balcony              26.094352
# Ownership            34.936624
# dtype: float64

# %%
# Rename Amount(in rupees) and Price (in rupees)
df.rename(columns = {'Amount(in rupees)': "Amount_in_rupees", 'Price (in rupees)': 'Price_in_rupees'}, inplace=True)

# %%
df.head()
# Out:
#                                                Title  \
# 0  1 BHK Ready to Occupy Flat for sale in Srushti...
# 1  2 BHK Ready to Occupy Flat for sale in Dosti V...
# 2  2 BHK Ready to Occupy Flat for sale in Sunrise...
# 3        1 BHK Ready to Occupy Flat for sale Kasheli
# 4  2 BHK Ready to Occupy Flat for sale in TenX Ha...
#
#                                          Description Amount_in_rupees  \
# 0  Bhiwandi, Thane has an attractive 1 BHK Flat f...          42 Lac
# 1  One can find this stunning 2 BHK flat for sale...          98 Lac
# 2  Up for immediate sale is a 2 BHK apartment in ...         1.40 Cr
# 3  This beautiful 1 BHK Flat is available for sal...          25 Lac
# 4  This lovely 2 BHK Flat in Pokhran Road, Thane ...         1.60 Cr
#
#    Price_in_rupees location Carpet Area         Status         Floor  \
# 0           6000.0    thane    500 sqft  Ready to Move  10 out of 11
# 1          13799.0    thane    473 sqft  Ready to Move   3 out of 22
# ...

# %%
df.Amount_in_rupees.unique()
# Out:
# array(['42 Lac ', '98 Lac ', '1.40 Cr ', ..., '1.5 Lac ', '24.4 Lac ',
#        '9.90 Cr '], dtype=object)

# %%
amounts = ['42 Cr', '98 Cr', '1.5 Lac', '24.4 Lac']

# %%
for x in '42 cr':
    print(x.lower().strip())
# Out:
# 4
# 2
#
# c
# r

# %%
price = '42 Lac'
price.replace('Lac', '')
print(price.replace('Lac', ''))
print(float(price.replace('Lac', '')) * 100000)
# Out:
# 42
# 4200000.0

# %%
def converter(price):
    if 'cr' in price.lower(): 
        a = float(price.lower().replace('cr', '')) * 10000000
        return a
    elif 'lac' in price.lower():
        b = float(price.lower().replace('lac', '')) * 100000
        return b
    else:
        return None

# %%
converter('42.2 cr')
# Out:
# 422000000.0

# %%
converter('30 Lac')
# Out:
# 3000000.0

# %%
df['Amount_in_rupees'] =  df.Amount_in_rupees.apply(converter)

# %%
df.head()
# Out:
#                                                Title  \
# 0  1 BHK Ready to Occupy Flat for sale in Srushti...
# 1  2 BHK Ready to Occupy Flat for sale in Dosti V...
# 2  2 BHK Ready to Occupy Flat for sale in Sunrise...
# 3        1 BHK Ready to Occupy Flat for sale Kasheli
# 4  2 BHK Ready to Occupy Flat for sale in TenX Ha...
#
#                                          Description  Amount_in_rupees  \
# 0  Bhiwandi, Thane has an attractive 1 BHK Flat f...         4200000.0
# 1  One can find this stunning 2 BHK flat for sale...         9800000.0
# 2  Up for immediate sale is a 2 BHK apartment in ...        14000000.0
# 3  This beautiful 1 BHK Flat is available for sal...         2500000.0
# 4  This lovely 2 BHK Flat in Pokhran Road, Thane ...        16000000.0
#
#    Price_in_rupees location Carpet Area         Status         Floor  \
# 0           6000.0    thane    500 sqft  Ready to Move  10 out of 11
# 1          13799.0    thane    473 sqft  Ready to Move   3 out of 22
# ...

# %%
df.isnull().mean() * 100
# Out:
# Title                0.000000
# Description          1.612000
# Amount_in_rupees     5.163946
# Price_in_rupees      9.419776
# location             0.000000
# Carpet Area         43.018488
# Status               0.327946
# Floor                3.773776
# Transaction          0.044259
# Furnishing           1.544811
# facing              37.451408
# overlooking         43.425354
# Bathroom             0.441527
# Balcony             26.094352
# Ownership           34.936624
# dtype: float64

# %%
df.head()
# Out:
#                                                Title  \
# 0  1 BHK Ready to Occupy Flat for sale in Srushti...
# 1  2 BHK Ready to Occupy Flat for sale in Dosti V...
# 2  2 BHK Ready to Occupy Flat for sale in Sunrise...
# 3        1 BHK Ready to Occupy Flat for sale Kasheli
# 4  2 BHK Ready to Occupy Flat for sale in TenX Ha...
#
#                                          Description  Amount_in_rupees  \
# 0  Bhiwandi, Thane has an attractive 1 BHK Flat f...         4200000.0
# 1  One can find this stunning 2 BHK flat for sale...         9800000.0
# 2  Up for immediate sale is a 2 BHK apartment in ...        14000000.0
# 3  This beautiful 1 BHK Flat is available for sal...         2500000.0
# 4  This lovely 2 BHK Flat in Pokhran Road, Thane ...        16000000.0
#
#    Price_in_rupees location Carpet Area         Status         Floor  \
# 0           6000.0    thane    500 sqft  Ready to Move  10 out of 11
# 1          13799.0    thane    473 sqft  Ready to Move   3 out of 22
# ...

# %%
categorical_features = df.select_dtypes(['object']).columns
categorical_features
# Out:
# Index(['Title', 'Description', 'location', 'Carpet Area', 'Status', 'Floor',
#        'Transaction', 'Furnishing', 'facing', 'overlooking', 'Bathroom',
#        'Balcony', 'Ownership'],
#       dtype='object')

# %% [markdown]
# ### Convert cover_area values into squareft

# %%
df['Carpet Area'].unique()
# Out:
# array(['500 sqft', '473 sqft', '779 sqft', ..., '1634 sqft', '164 sqyrd',
#        '136 sqft'], dtype=object)

# %%
def convert_sqft(area):
    if 'sqft' in area:
        a = float(area.lower().replace('sqft', ''))
        return a
    elif 'sqyrd' in area:
        b = float(area.lower().replace('sqyrd', '')) * 9
        return b
    else:
        return None

# %%
convert_sqft('500.2')

# %%
# Convert values under carpet area to string as apply rhe convert_sqft function
df['Carpet Area'] = df['Carpet Area'].astype('str').apply(convert_sqft)

# %%
df['Carpet Area']
# Out:
# 0          500.0
# 1          473.0
# 2          779.0
# 3          530.0
# 4          635.0
#            ...
# 187526       NaN
# 187527       NaN
# 187528    1250.0
# 187529       NaN
# 187530       NaN
# Name: Carpet Area, Length: 187531, dtype: float64

# %%
df.head()
# Out:
#                                                Title  \
# 0  1 BHK Ready to Occupy Flat for sale in Srushti...
# 1  2 BHK Ready to Occupy Flat for sale in Dosti V...
# 2  2 BHK Ready to Occupy Flat for sale in Sunrise...
# 3        1 BHK Ready to Occupy Flat for sale Kasheli
# 4  2 BHK Ready to Occupy Flat for sale in TenX Ha...
#
#                                          Description  Amount_in_rupees  \
# 0  Bhiwandi, Thane has an attractive 1 BHK Flat f...         4200000.0
# 1  One can find this stunning 2 BHK flat for sale...         9800000.0
# 2  Up for immediate sale is a 2 BHK apartment in ...        14000000.0
# 3  This beautiful 1 BHK Flat is available for sal...         2500000.0
# 4  This lovely 2 BHK Flat in Pokhran Road, Thane ...        16000000.0
#
#    Price_in_rupees location  Carpet Area         Status         Floor  \
# 0           6000.0    thane        500.0  Ready to Move  10 out of 11
# 1          13799.0    thane        473.0  Ready to Move   3 out of 22
# ...

# %%
categorical_features
# Out:
# Index(['Title', 'Description', 'location', 'Carpet Area', 'Status', 'Floor',
#        'Transaction', 'Furnishing', 'facing', 'overlooking', 'Bathroom',
#        'Balcony', 'Ownership'],
#       dtype='object')

# %%
categorical_features = df.select_dtypes(['object']).columns
categorical_features
# Out:
# Index(['Title', 'Description', 'location', 'Status', 'Floor', 'Transaction',
#        'Furnishing', 'facing', 'overlooking', 'Bathroom', 'Balcony',
#        'Ownership'],
#       dtype='object')

# %%
df.Bathroom.unique()
# Out:
# array(['1', '2', '3', '4', '6', nan, '5', '10', '9', '8', '> 10', '7'],
#       dtype=object)

# %%
# Replace > 10 with 11
df.Bathroom.replace({'> 10': '11'}, inplace =True)
# Out:
# C:\Users\uniqu\AppData\Local\Temp\ipykernel_19088\2447890513.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Bathroom.replace({'> 10': '11'}, inplace =True)

# %%
df.Bathroom.unique()
# Out:
# array(['1', '2', '3', '4', '6', nan, '5', '10', '9', '8', '11', '7'],
#       dtype=object)

# %%
# Convert Bathroom column from object to int type
df["Bathroom"] = df["Bathroom"].astype('float')

# %%
categorical_features = df.select_dtypes(['object']).columns
categorical_features
# Out:
# Index(['Title', 'Description', 'location', 'Status', 'Floor', 'Transaction',
#        'Furnishing', 'facing', 'overlooking', 'Balcony', 'Ownership'],
#       dtype='object')

# %%
df['Balcony'].unique()
# Out:
# array(['2', nan, '1', '3', '4', '> 10', '6', '5', '7', '10', '8', '9'],
#       dtype=object)

# %%
# Replace > 10 with 11
df.Balcony.replace({'> 10': '11'}, inplace =True)
# Out:
# C:\Users\uniqu\AppData\Local\Temp\ipykernel_19088\3451273499.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.Balcony.replace({'> 10': '11'}, inplace =True)

# %%
# Convert Balcony from Object into float
df['Balcony'] = df['Balcony'].astype('float')

# %% [markdown]
# ### Fill categorical columns with mode()

# %%
categorical_features = df.select_dtypes(['object']).columns
categorical_features
# Out:
# Index(['Title', 'Description', 'location', 'Status', 'Floor', 'Transaction',
#        'Furnishing', 'facing', 'overlooking', 'Ownership'],
#       dtype='object')

# %%
# df.fillna('Furnishing', df['Furnishing'].mode()[0], inplace = True)

# %%
for x in categorical_features:
    df[x].fillna(df[x].mode()[0], inplace = True)
# Out:
# C:\Users\uniqu\AppData\Local\Temp\ipykernel_19088\2370285712.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[x].fillna(df[x].mode()[0], inplace = True)

# %% [markdown]
# ### Fill numerical columns with mean()

# %%
df.isnull().mean() * 100
# Out:
# Title                0.000000
# Description          0.000000
# Amount_in_rupees     5.163946
# Price_in_rupees      9.419776
# location             0.000000
# Carpet Area         43.500541
# Status               0.000000
# Floor                0.000000
# Transaction          0.000000
# Furnishing           0.000000
# facing               0.000000
# overlooking          0.000000
# Bathroom             0.441527
# Balcony             26.094352
# Ownership            0.000000
# dtype: float64

# %%
numerical_features = df.select_dtypes(['int64', 'float64']).columns
numerical_features
# Out:
# Index(['Amount_in_rupees', 'Price_in_rupees', 'Carpet Area', 'Bathroom',
#        'Balcony'],
#       dtype='object')

# %%
# df['Amount_in_rupees'].fillna(df['Amount_in_rupees'].mean(), inplace = True)

# %%
for x in numerical_features:
    df[x].fillna(df[x].mean(), inplace = True)
# Out:
# C:\Users\uniqu\AppData\Local\Temp\ipykernel_19088\1458916631.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[x].fillna(df[x].mean(), inplace = True)

# %%
df.isnull().mean() * 100
# Out:
# Title               0.0
# Description         0.0
# Amount_in_rupees    0.0
# Price_in_rupees     0.0
# location            0.0
# Carpet Area         0.0
# Status              0.0
# Floor               0.0
# Transaction         0.0
# Furnishing          0.0
# facing              0.0
# overlooking         0.0
# Bathroom            0.0
# Balcony             0.0
# Ownership           0.0
# dtype: float64

# %%
df.head()
# Out:
#                                                Title  \
# 0  1 BHK Ready to Occupy Flat for sale in Srushti...
# 1  2 BHK Ready to Occupy Flat for sale in Dosti V...
# 2  2 BHK Ready to Occupy Flat for sale in Sunrise...
# 3        1 BHK Ready to Occupy Flat for sale Kasheli
# 4  2 BHK Ready to Occupy Flat for sale in TenX Ha...
#
#                                          Description  Amount_in_rupees  \
# 0  Bhiwandi, Thane has an attractive 1 BHK Flat f...         4200000.0
# 1  One can find this stunning 2 BHK flat for sale...         9800000.0
# 2  Up for immediate sale is a 2 BHK apartment in ...        14000000.0
# 3  This beautiful 1 BHK Flat is available for sal...         2500000.0
# 4  This lovely 2 BHK Flat in Pokhran Road, Thane ...        16000000.0
#
#    Price_in_rupees location  Carpet Area         Status         Floor  \
# 0      6000.000000    thane        500.0  Ready to Move  10 out of 11
# 1     13799.000000    thane        473.0  Ready to Move   3 out of 22
# ...

# %%
print(df.Status.unique())
print(df.Transaction.unique())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19088\1337619260.py in ?()
# ----> 1 print(df.Status.unique())
#       2 print(df.Transaction.unique())
#
# ~\miniconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'Status'

# %%
# Removing the title, description and status column
df.drop(['Title', 'Description', 'Status', 'Floor'], axis = 1, inplace= True)

# %%
df.head()
# Out:
#    Amount_in_rupees  Price_in_rupees location  Carpet Area Transaction  \
# 0         4200000.0      6000.000000    thane        500.0      Resale
# 1         9800000.0     13799.000000    thane        473.0      Resale
# 2        14000000.0     17500.000000    thane        779.0      Resale
# 3         2500000.0      7583.771885    thane        530.0      Resale
# 4        16000000.0     18824.000000    thane        635.0      Resale
#
#        Furnishing facing             overlooking  Bathroom   Balcony  \
# 0     Unfurnished   East               Main Road       1.0  2.000000
# 1  Semi-Furnished   East             Garden/Park       2.0  2.001782
# 2     Unfurnished   East             Garden/Park       2.0  2.001782
# 3     Unfurnished   East               Main Road       1.0  1.000000
# 4     Unfurnished   West  Garden/Park, Main Road       2.0  2.001782
#
#               Ownership
# 0              Freehold
# 1              Freehold
# 2              Freehold
# ...

# %%
categorical_features = df.select_dtypes(['object']).columns
categorical_features
# Out:
# Index(['location', 'Transaction', 'Furnishing', 'facing', 'overlooking',
#        'Ownership'],
#       dtype='object')

# %%
for x in categorical_features:
    print(df[x].unique())
# Out:
# ['thane' 'navi-mumbai' 'nagpur' 'mumbai' 'ahmedabad' 'bangalore' 'chennai'
#  'gurgaon' 'hyderabad' 'indore' 'jaipur' 'kolkata' 'lucknow' 'new-delhi'
#  'noida' 'pune' 'agra' 'ahmadnagar' 'allahabad' 'aurangabad' 'badlapur'
#  'belgaum' 'bhiwadi' 'bhiwandi' 'bhopal' 'bhubaneswar' 'chandigarh'
#  'coimbatore' 'dehradun' 'durgapur' 'ernakulam' 'faridabad' 'ghaziabad'
#  'goa' 'greater-noida' 'guntur' 'guwahati' 'gwalior' 'haridwar' 'jabalpur'
#  'jamshedpur' 'jodhpur' 'kalyan' 'kanpur' 'kochi' 'kozhikode' 'ludhiana'
#  'madurai' 'mangalore' 'mohali' 'mysore' 'nashik' 'navsari' 'nellore'
#  'palakkad' 'palghar' 'panchkula' 'patna' 'pondicherry' 'raipur'
#  'rajahmundry' 'ranchi' 'satara' 'shimla' 'siliguri' 'solapur' 'sonipat'
#  'surat' 'thrissur' 'tirupati' 'trichy' 'trivandrum' 'udaipur' 'udupi'
#  'vadodara' 'vapi' 'varanasi' 'vijayawada' 'visakhapatnam' 'vrindavan'
#  'zirakpur']
# ['Resale' 'New Property' 'Other' 'Rent/Lease']
# ['Unfurnished' 'Semi-Furnished' 'Furnished']
# ...

# %%
# Correlation between numerical varialble/features
df[numerical_features].corr()
# Out:
#                   Amount_in_rupees  Price_in_rupees  Carpet Area  Bathroom  \
# Amount_in_rupees          1.000000         0.760839     0.047312  0.208294
# Price_in_rupees           0.760839         1.000000     0.008894  0.056896
# Carpet Area               0.047312         0.008894     1.000000  0.145535
# Bathroom                  0.208294         0.056896     0.145535  1.000000
# Balcony                   0.102743         0.034366     0.074701  0.361922
#
#                    Balcony
# Amount_in_rupees  0.102743
# Price_in_rupees   0.034366
# Carpet Area       0.074701
# Bathroom          0.361922
# Balcony           1.000000

# %% [markdown]
# ### Data encoding for categorical columns

# %%
categorical_features
# Out:
# Index(['location', 'Transaction', 'Furnishing', 'facing', 'overlooking',
#        'Ownership'],
#       dtype='object')

# %%
# from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder

# %%
# Initialize labelEncoder
label_enc = LabelEncoder()

# %%
# df['location'] = label_enc.fit_transform.(df['location'])

# %%
for x in categorical_features:
    df[x] =  label_enc.fit_transform(df[x])

# %%
df.head()
# Out:
#    Amount_in_rupees  Price_in_rupees  location  Carpet Area  Transaction  \
# 0         4200000.0      6000.000000        67        500.0            3
# 1         9800000.0     13799.000000        67        473.0            3
# 2        14000000.0     17500.000000        67        779.0            3
# 3         2500000.0      7583.771885        67        530.0            3
# 4        16000000.0     18824.000000        67        635.0            3
#
#    Furnishing  facing  overlooking  Bathroom   Balcony  Ownership
# 0           2       0            7       1.0  2.000000          1
# 1           1       0            0       2.0  2.001782          1
# 2           2       0            0       2.0  2.001782          1
# 3           2       0            7       1.0  1.000000          1
# 4           2       7            1       2.0  2.001782          0

# %% [markdown]
# #### Creating X(input) and Y(output) features for ML model

# %%
y = df.Amount_in_rupees
# x = df[['Price_in_rupees', 'location', 'carpet Area']]
x = df.drop('Amount_in_rupees', axis=1)

# %%
x.head()
# Out:
#    Price_in_rupees  location  Carpet Area  Transaction  Furnishing  facing  \
# 0      6000.000000        67        500.0            3           2       0
# 1     13799.000000        67        473.0            3           1       0
# 2     17500.000000        67        779.0            3           2       0
# 3      7583.771885        67        530.0            3           2       0
# 4     18824.000000        67        635.0            3           2       7
#
#    overlooking  Bathroom   Balcony  Ownership
# 0            7       1.0  2.000000          1
# 1            0       2.0  2.001782          1
# 2            0       2.0  2.001782          1
# 3            7       1.0  1.000000          1
# 4            1       2.0  2.001782          0

# %%
y.head()
# Out:
# 0     4200000.0
# 1     9800000.0
# 2    14000000.0
# 3     2500000.0
# 4    16000000.0
# Name: Amount_in_rupees, dtype: float64

# %% [markdown]
# #### Standardize X(input)  using standard scaler

# %% [markdown]
# #### Split data into training and test set

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state= 10)

# %%
print(x.shape)
print(x_train.shape)
print(x_test.shape)
# Out:
# (187531, 10)
# (140648, 10)
# (46883, 10)

# %%
print(y.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (187531,)
# (140648,)
# (46883,)

# %% [markdown]
# #### Model Training

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
# Initialize the model
LR = LinearRegression()

# %%
LR.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# #### Model Evaluation

# %%
LR.predict(x_test)
# Out:
# array([12450202.30892339,  2974020.82588423,  4925265.63747359, ...,
#         7773006.79114454,  8126110.12761654, -4170172.05882628])

# %%
predicted_values = LR.predict(x_test)

# %%
mean_squared_error(predicted_values, y_test)
# Out:
# 80392069449143.86

# %%
LR.predict([[6000, 67, 500, 3, 2, 0, 7, 1, 2, 1]])
# Out:
# C:\Users\uniqu\miniconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([795487.8260731])

# %%
df
# Out:
#         Amount_in_rupees  Price_in_rupees  location  Carpet Area  Transaction  \
# 0              4200000.0      6000.000000        67   500.000000            3
# 1              9800000.0     13799.000000        67   473.000000            3
# 2             14000000.0     17500.000000        67   779.000000            3
# 3              2500000.0      7583.771885        67   530.000000            3
# 4             16000000.0     18824.000000        67   635.000000            3
# ...                  ...              ...       ...          ...          ...
# 187526         6300000.0      3225.000000        80  1262.585292            0
# 187527         5500000.0      3274.000000        80  1262.585292            3
# 187528         7600000.0      4343.000000        80  1250.000000            3
# 187529         3000000.0      4231.000000        80  1262.585292            3
# 187530        11800000.0      6162.000000        80  1262.585292            3
#
# ...

# %%
LR.intercept_
# Out:
# -13335557.922227452

# %%
plt.scatter(y_test, predicted_values)
plt.plot(y_test, y_test, c= "red")
plt.show()

# %% [markdown]
# #### Standardize X(input)  using MinMax Scaler

# %%
x.head()
# Out:
#    Price_in_rupees  location  Carpet Area  Transaction  Furnishing  facing  \
# 0      6000.000000        67        500.0            3           2       0
# 1     13799.000000        67        473.0            3           1       0
# 2     17500.000000        67        779.0            3           2       0
# 3      7583.771885        67        530.0            3           2       0
# 4     18824.000000        67        635.0            3           2       7
#
#    overlooking  Bathroom   Balcony  Ownership
# 0            7       1.0  2.000000          1
# 1            0       2.0  2.001782          1
# 2            0       2.0  2.001782          1
# 3            7       1.0  1.000000          1
# 4            1       2.0  2.001782          0

# %%
# Scaling the Price_in_rupees and carpet area
from sklearn.preprocessing import MinMaxScaler

# %%
#initialize standard scaler
scaler = MinMaxScaler()

# %%
scaler.fit_transform(x[['Price_in_rupees', 'Carpet Area']])
# Out:
# array([[0.00089552, 0.00070359],
#        [0.00205955, 0.00066552],
#        [0.00261194, 0.00109698],
#        ...,
#        [0.00064821, 0.00176109],
#        [0.00063149, 0.00177883],
#        [0.0009197 , 0.00177883]])

# %%
x[['Price_in_rupees', 'Carpet Area']] = scaler.fit_transform(x[['Price_in_rupees', 'Carpet Area']])

# %%
x.head()
# Out:
#    Price_in_rupees  location  Carpet Area  Transaction  Furnishing  facing  \
# 0         0.000896        67     0.000704            3           2       0
# 1         0.002060        67     0.000666            3           1       0
# 2         0.002612        67     0.001097            3           2       0
# 3         0.001132        67     0.000746            3           2       0
# 4         0.002810        67     0.000894            3           2       7
#
#    overlooking  Bathroom   Balcony  Ownership
# 0            7       1.0  2.000000          1
# 1            0       2.0  2.001782          1
# 2            0       2.0  2.001782          1
# 3            7       1.0  1.000000          1
# 4            1       2.0  2.001782          0

# %%
# Split x and Y into train and test
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state= 20)

# %%
#Initialize model
LR = LinearRegression()
LR.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
predicted_values = LR.predict(x_test)

# %%
mean_squared_error(predicted_values, y_test)
# Out:
# 72690340989012.1

# %% [markdown]
# ### Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
# initialize the regressor
rf = RandomForestRegressor(random_state=40)

# %%
rf.fit(x_train, y_train)
# Out:
# RandomForestRegressor(random_state=40)

# %%
rf.predict(x_test)
# Out:
# array([39687000.,  4000000.,  5000000., ...,  4122500., 18841000.,
#        19200000.])

# %%
predicted_values = rf.predict(x_test)

# %%
mean_squared_error(predicted_values, y_test)
# Out:
# 12740693760398.672

# %% [markdown]
# #### Accuracy score

# %%
from sklearn.metrics import r2_score

# %%
y_pred_lr = LR.predict(x_test)
y_pred_rf = rf.predict(x_test)

# %%
print('Accuracy score of Linear regression model is', r2_score(y_test, y_pred_lr))
print('Accuracy score of Random forest regressor model is', r2_score(y_test, y_pred_rf))
# Out:
# Accuracy score of Linear regression model is 0.6030190885621032
# Accuracy score of Random forest regressor model is 0.9304197483112822
